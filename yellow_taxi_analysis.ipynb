# %% [markdown]
# Pull the following from this link https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# - Taxi trip records from 4 sources
#
# - Associated data dictionaries
#
# - Taxi zone lookups
#
# Answer the following questions about the effects of the Corona Virus on taxi transportation in NYC:
#
# 1. What has been the economic impact of the pandemic on NYC taxi revenue over time?
#
# 2. What was the most expensive trip? Between what zones? Conversely, what was the cheapest trip? What is the difference between these before and during the peak impact of the pandemic?
#
# 3. What's the most popular payment method? Did this change because of the pandemic?
#
# 4. What’s the most expensive day of the week to travel on? Did this change because of the pandemic?

# %% [markdown]
# ## Cleaning and Downloading

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# merging 12 csv files for yellow axis in 2019
df_yellow_2019 = pd.concat(
    map(pd.read_csv, [
                      '/content/drive/MyDrive/Spekit data/2019/01/yellow_tripdata_2019-01.csv', 
                      '/content/drive/MyDrive/Spekit data/2019/02/yellow_tripdata_2019-02.csv',
                      '/content/drive/MyDrive/Spekit data/2019/03/yellow_tripdata_2019-03.csv',
                      '/content/drive/MyDrive/Spekit data/2019/04/yellow_tripdata_2019-04.csv',
                      '/content/drive/MyDrive/Spekit data/2019/05/yellow_tripdata_2019-05.csv',
                      '/content/drive/MyDrive/Spekit data/2019/06/yellow_tripdata_2019-06.csv',
                      '/content/drive/MyDrive/Spekit data/2019/07/yellow_tripdata_2019-07.csv',
                      '/content/drive/MyDrive/Spekit data/2019/08/yellow_tripdata_2019-08.csv',
                      '/content/drive/MyDrive/Spekit data/2019/09/yellow_tripdata_2019-09.csv',
                      '/content/drive/MyDrive/Spekit data/2019/10/yellow_tripdata_2019-10.csv',
                      '/content/drive/MyDrive/Spekit data/2019/11/yellow_tripdata_2019-11.csv',
                      '/content/drive/MyDrive/Spekit data/2019/12/yellow_tripdata_2019-12.csv'
                      ]), ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# merging 12 csv files for yellow axis in 2020
df_yellow_2020 = pd.concat(
    map(pd.read_csv, [
                      '/content/drive/MyDrive/Spekit data/2020/01/yellow_tripdata_2020-01.csv', 
                      '/content/drive/MyDrive/Spekit data/2020/02/yellow_tripdata_2020-02.csv',
                      '/content/drive/MyDrive/Spekit data/2020/03/yellow_tripdata_2020-03.csv',
                      '/content/drive/MyDrive/Spekit data/2020/04/yellow_tripdata_2020-04.csv',
                      '/content/drive/MyDrive/Spekit data/2020/05/yellow_tripdata_2020-05.csv',
                      '/content/drive/MyDrive/Spekit data/2020/06/yellow_tripdata_2020-06.csv',
                      '/content/drive/MyDrive/Spekit data/2020/07/yellow_tripdata_2020-07.csv',
                      '/content/drive/MyDrive/Spekit data/2020/08/yellow_tripdata_2020-08.csv',
                      '/content/drive/MyDrive/Spekit data/2020/09/yellow_tripdata_2020-09.csv',
                      '/content/drive/MyDrive/Spekit data/2020/10/yellow_tripdata_2020-10.csv',
                      '/content/drive/MyDrive/Spekit data/2020/11/yellow_tripdata_2020-11.csv',
                      '/content/drive/MyDrive/Spekit data/2020/12/yellow_tripdata_2020-12.csv'
                      ]), ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# merging 7 csv files for yellow axis in 2021
df_yellow_2021 = pd.concat(
    map(pd.read_csv, [
                      '/content/drive/MyDrive/Spekit data/2021/01/yellow_tripdata_2021-01.csv', 
                      '/content/drive/MyDrive/Spekit data/2021/02/yellow_tripdata_2021-02.csv',
                      '/content/drive/MyDrive/Spekit data/2021/03/yellow_tripdata_2021-03.csv',
                      '/content/drive/MyDrive/Spekit data/2021/04/yellow_tripdata_2021-04.csv',
                      '/content/drive/MyDrive/Spekit data/2021/05/yellow_tripdata_2021-05.csv',
                      '/content/drive/MyDrive/Spekit data/2021/06/yellow_tripdata_2021-06.csv',
                      '/content/drive/MyDrive/Spekit data/2021/07/yellow_tripdata_2021-07.csv'
                      ]), ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# convert date columns to dt
df_yellow_2019['tpep_pickup_datetime'] = pd.to_datetime(df_yellow_2019['tpep_pickup_datetime'])
df_yellow_2019['tpep_dropoff_datetime'] = pd.to_datetime(df_yellow_2019['tpep_dropoff_datetime'])
df_yellow_2020['tpep_pickup_datetime'] = pd.to_datetime(df_yellow_2020['tpep_pickup_datetime'])
df_yellow_2020['tpep_dropoff_datetime'] = pd.to_datetime(df_yellow_2020['tpep_dropoff_datetime'])
df_yellow_2021['tpep_pickup_datetime'] = pd.to_datetime(df_yellow_2021['tpep_pickup_datetime'])
df_yellow_2021['tpep_dropoff_datetime'] = pd.to_datetime(df_yellow_2021['tpep_dropoff_datetime'])

# %%
sns.boxplot(x=df_yellow_2019['fare_amount'])

# %%
df_yellow_2019.sort_values('fare_amount', ascending=False)
# Out:
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 18531143       1.0  2019-03-15 19:00:45  ...   1084772.17                   2.5
# 13812910       1.0  2019-02-25 18:43:23  ...    671124.94                   0.0
# 2499600        1.0  2019-01-11 19:33:15  ...    623261.66                   NaN
# 53447745       1.0  2019-08-14 12:35:43  ...    411042.81                   0.0
# 81314723       1.0  2019-12-16 15:37:05  ...    398471.20                   2.5
# ...            ...                  ...  ...          ...                   ...
# 80452861       2.0  2019-12-13 03:19:34  ...      -500.30                   0.0
# 62843726       2.0  2019-09-28 11:24:37  ...      -530.80                   0.0
# 82244784       2.0  2019-12-20 00:32:51  ...      -602.80                  -2.5
# 81777213       2.0  2019-12-18 12:48:52  ...     -1472.80                   0.0
# 51653336       2.0  2019-08-05 13:51:30  ...     -1871.80                   0.0
#
# ...

# %%
yellow_2019_mean = df_yellow_2019['fare_amount'].mean()
yellow_2019_std = df_yellow_2019['fare_amount'].std()
yellow_2019_right = yellow_2019_mean + (yellow_2019_std * 3)
yellow_2019_left = yellow_2019_mean - (yellow_2019_std * 3)

df_yellow_2019.drop(df_yellow_2019[df_yellow_2019['fare_amount'] < yellow_2019_left].index, inplace = True)
df_yellow_2019.drop(df_yellow_2019[df_yellow_2019['fare_amount'] > yellow_2019_right].index, inplace = True)

# %%
df_yellow_2019.sort_values('fare_amount', ascending=False)
# Out:
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 54463043       2.0  2019-08-19 17:43:54  ...       536.80                   0.0
# 51468250       2.0  2019-08-04 12:47:13  ...       535.28                   0.0
# 67415855       1.0  2019-10-18 14:05:09  ...       537.30                   2.5
# 53211456       2.0  2019-08-13 10:34:10  ...       557.54                   0.0
# 30108954       2.0  2019-05-01 17:21:29  ...       531.80                   0.0
# ...            ...                  ...  ...          ...                   ...
# 24561545       2.0  2019-04-09 01:35:20  ...      -450.88                   0.0
# 55872466       2.0  2019-08-26 23:44:42  ...      -486.30                  -2.5
# 56989953       2.0  2019-09-01 23:19:56  ...      -497.30                   0.0
# 61013463       2.0  2019-09-20 05:39:02  ...      -498.80                   0.0
# 80452861       2.0  2019-12-13 03:19:34  ...      -500.30                   0.0
#
# ...

# %%
df_yellow_2019.drop(df_yellow_2019[df_yellow_2019['fare_amount'] < 1].index, inplace = True)
df_yellow_2019 = df_yellow_2019.sort_values('fare_amount', ascending=False)

# %%
yellow_2020_mean = df_yellow_2020['fare_amount'].mean()
yellow_2020_std = df_yellow_2020['fare_amount'].std()
yellow_2020_right = yellow_2020_mean + (yellow_2020_std * 3)
yellow_2020_left = yellow_2020_mean - (yellow_2020_std * 3)

df_yellow_2020.drop(df_yellow_2020[df_yellow_2020['fare_amount'] < 1].index, inplace = True)
df_yellow_2020.drop(df_yellow_2020[df_yellow_2020['fare_amount'] > yellow_2020_right].index, inplace = True)

df_yellow_2020 = df_yellow_2020.sort_values('fare_amount', ascending=False)


yellow_2021_mean = df_yellow_2021['fare_amount'].mean()
yellow_2021_std = df_yellow_2021['fare_amount'].std()
yellow_2021_right = yellow_2021_mean + (yellow_2021_std * 3)
yellow_2021_left = yellow_2021_mean - (yellow_2021_std * 3)

df_yellow_2021.drop(df_yellow_2021[df_yellow_2021['fare_amount'] < 1].index, inplace = True)
df_yellow_2021.drop(df_yellow_2021[df_yellow_2021['fare_amount'] > yellow_2021_right].index, inplace = True)

df_yellow_2021 = df_yellow_2021.sort_values('fare_amount', ascending=False)

# %%
df_yellow_2019.to_csv('/content/drive/MyDrive/Spekit data/df_yellow_2019')
df_yellow_2020.to_csv('/content/drive/MyDrive/Spekit data/df_yellow_2020')
df_yellow_2021.to_csv('/content/drive/MyDrive/Spekit data/df_yellow_2021')

# %% [markdown]
# ## Analysis

# %% [markdown]
# 1. What has been the economic impact of the pandemic on NYC taxi revenue over time?

# %% [markdown]
# Not including taxes, tips, and surcharges

# %%
yellow_rev_2019 = df_yellow_2019['total_amount'].sum() - df_yellow_2019['tip_amount'].sum()
yellow_rev_2020 = df_yellow_2020['total_amount'].sum() - df_yellow_2020['tip_amount'].sum()
yellow_rev_2021 = df_yellow_2021['total_amount'].sum() - df_yellow_2021['tip_amount'].sum()

print('Yellow Taxi Revenue')
print('2019 Total Fare Revenue: ${: 9,.2f}'.format(yellow_rev_2019))
print('2020 Total Fare Revenue: $  {: 9,.2f}'.format(yellow_rev_2020))
print('2021 Total Fare Revenue: $  {: 9,.2f}'.format(yellow_rev_2021))
# Out:
# Yellow Taxi Revenue
# 2019 Total Fare Revenue: $ 1,425,878,300.91
# 2020 Total Fare Revenue: $   401,253,032.91
# 2021 Total Fare Revenue: $   248,255,705.67

# %% [markdown]
# Calculate the percent change from 2019 to 2020

# %%
yellow_pct_chg = (yellow_rev_2020 - yellow_rev_2019) / yellow_rev_2019
print('{:.2%}'.format(yellow_pct_chg))
# Out:
# -71.86%

# %% [markdown]
# 2. What was the most expensive trip? Between what zones? Conversely, what was the cheapest trip? What is the difference between these before and during the peak impact of the pandemic?

# %%
display(df_yellow_2019.head(2))
display(df_yellow_2020.head(1))
display(df_yellow_2021.head(1))
# Out:
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 54463043       2.0  2019-08-19 17:43:54  ...       536.80                   0.0
# 51468250       2.0  2019-08-04 12:47:13  ...       535.28                   0.0
#
# [2 rows x 18 columns]
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 15942941       NaN  2020-04-24 20:23:00  ...         56.7                   2.5
#
# [1 rows x 18 columns]
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 12079539       NaN  2021-06-05 17:47:00  ...         51.4                   2.5
#
# [1 rows x 18 columns]

# %%
display(df_yellow_2019.tail(1))
display(df_yellow_2020.tail(1))
display(df_yellow_2021.tail(1))
# Out:
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 60908673       1.0  2019-09-19 18:20:13  ...          1.3                   0.0
#
# [1 rows x 18 columns]
#           VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 21871921       1.0  2020-11-05 10:52:04  ...          1.3                   0.0
#
# [1 rows x 18 columns]
#          VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 7633328       2.0  2021-05-11 17:34:34  ...          3.8                   2.5
#
# [1 rows x 18 columns]

# %% [markdown]
# 3. What's the most popular payment method? Did this change because of the pandemic?

# %%
# find most common payment methods in 2020
print(df_yellow_2019['payment_type'].mode())
print(df_yellow_2020['payment_type'].mode())
print(df_yellow_2021['payment_type'].mode())
# Out:
# 0    1.0
# dtype: float64
# 0    1.0
# dtype: float64
# 0    1.0
# dtype: float64

# %%
display(df_yellow_2019['payment_type'].value_counts())
# Out:
# 1.0    60622269
# 2.0    22896312
# 3.0      447241
# 4.0      186563
# 5.0          33
# Name: payment_type, dtype: int64

# %%
# count len payment_type without the NaN values
total_pay_yellow_2019 = (np.count_nonzero(~np.isnan(df_yellow_2019['payment_type'])))
total_pay_yellow_2020 = (np.count_nonzero(~np.isnan(df_yellow_2020['payment_type'])))

# %%
# Yellow payment types
print('Percent of Fares Paid W/ Card 2019: {:.2%}'.format(len(df_yellow_2019.loc[df_yellow_2019['payment_type'] == 1]) / total_pay_yellow_2019))
print('Percent of Fares Paid W/ Card 2020: {:.2%}'.format(len(df_yellow_2020.loc[df_yellow_2020['payment_type'] == 1]) / total_pay_yellow_2020))

print('Percent of Fares Paid W/ Cash 2019: {:.2%}'.format(len(df_yellow_2019.loc[df_yellow_2019['payment_type'] == 2]) / total_pay_yellow_2019))
print('Percent of Fares Paid W/ Cash 2020: {:.2%}'.format(len(df_yellow_2020.loc[df_yellow_2020['payment_type'] == 2]) / total_pay_yellow_2020))
# Out:
# Percent of Fares Paid W/ Card 2019: 72.21%
# Percent of Fares Paid W/ Card 2020: 73.54%
# Percent of Fares Paid W/ Cash 2019: 27.23%
# Percent of Fares Paid W/ Cash 2020: 25.82%

# %% [markdown]
# 4. What’s the most expensive day of the week to travel on? Did this change because of the pandemic?

# %%
df_yellow_2019['weekday'] = df_yellow_2019['tpep_pickup_datetime'].dt.day_name()
df_yellow_2020['weekday'] = df_yellow_2020['tpep_pickup_datetime'].dt.day_name()
df_yellow_2021['weekday'] = df_yellow_2021['tpep_pickup_datetime'].dt.day_name()

# %%
daily_avg_2019 = df_yellow_2019.groupby('weekday').mean('fare_amount')
daily_avg_2019 = daily_avg_2019[['fare_amount']]
daily_avg_2019
# Out:
#            fare_amount
# weekday
# Friday       13.474965
# Monday       13.508182
# Saturday     12.719188
# Sunday       13.498118
# Thursday     13.613490
# Tuesday      13.201896
# Wednesday    13.355484

# %%
daily_avg_2020 = df_yellow_2020.groupby('weekday').mean('fare_amount')
daily_avg_2020 = daily_avg_2020[['fare_amount']]
daily_avg_2020
# Out:
#            fare_amount
# weekday
# Friday       12.707630
# Monday       12.855804
# Saturday     12.144811
# Sunday       13.013195
# Thursday     12.734298
# Tuesday      12.529710
# Wednesday    12.578321

# %%
daily_avg_2021 = df_yellow_2021.groupby('weekday').mean('fare_amount')
daily_avg_2021 = daily_avg_2021[['fare_amount']]
daily_avg_2021
# Out:
#            fare_amount
# weekday
# Friday       12.906173
# Monday       12.960993
# Saturday     12.601927
# Sunday       13.518432
# Thursday     12.867647
# Tuesday      12.610503
# Wednesday    12.584217
